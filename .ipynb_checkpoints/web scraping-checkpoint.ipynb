# %%
### Open File and prepare Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("515k-hotel-reviews-data-in-europe.zip")

# %%
df.Hotel_Address[0].split()[-1]
# Out:
# 'Netherlands'

# %%
def get_country(adress):
    country = adress.split()[-1]
    if country == "Kingdom":
        return("United Kingdom")
    else:
        return(country)
    
df['Country'] = df.Hotel_Address.apply(lambda x: get_country(x))
df.Country.value_counts()
# Out:
# United Kingdom    262301
# Spain              60149
# France             59928
# Netherlands        57214
# Austria            38939
# Italy              37207
# Name: Country, dtype: int64

# %%
def get_city(adress, country):
    city = adress.split()[-2]
    if country == "United Kingdom":
        return(adress.split()[-5])
    else:
        return(city)

df['City'] = df[['Hotel_Address','Country']].apply(lambda x: get_city(x[0], x[1]), axis=1)
df.City.value_counts()

# %% [markdown]
# ### Scrapping Hotel Prices
# There's a lot more of information missing which we think is important to get better insights.
# To get all this information the first thing i need is to get the exact address that directs me into the booking page containing information of each Hotel.
# This first step will be done through scrapping the links in Google.
# Once scrapped the final address in booking, another scrapping exercise will be needed in order to get the desired information for each Hotel.

# %%
scrap = df[['Hotel_Name','City']].groupby(['Hotel_Name','City']).count().reset_index()
scrap = scrap.apply(lambda x: ('Hotel ' + x[0] + ' ' + x[1]), axis=1)
scrap.head()
# Out:
# 0                    Hotel 11 Cadogan Gardens London
# 1                               Hotel 1K Hotel Paris
# 2    Hotel 25hours Hotel beim MuseumsQuartier Vienna
# 3                                    Hotel 41 London
# 4    Hotel 45 Park Lane Dorchester Collection London
# dtype: object

# %% [markdown]
# This is the adress i will use in Google. The idea is that i will pick the first adress coming from booking.com as the final address of the hotel in the sistem. Once i will gather all of the addresses i will try to scrap the prices in each one of them

# %%
google = ['https://www.google.com/search?sxsrf=&q=booking.com'+i.replace(" ", "+") for i in scrap]

# %% [markdown]
# Once i've got all the addresses of a Google search i start scrapping the addresses in Booking

# %% [markdown]
# #### Scrapping of Booking addresses

# %%
import requests
from bs4 import BeautifulSoup

# %%
bookingadress = []
for i, hotel in enumerate(google[:15]):
    URL = hotel
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    bkng = []
    for page in soup.find_all('a', href=True):
        if page['href'][:37] == '/url?q=https://www.booking.com/hotel/':
            bkng.append(page['href'][7:].split('&', 1)[0])
    if bkng[0][-8:] != '.es.html':
        bkng[0] = bkng[0][:-5]+'.es.html'
        
    bookingadress.append(bkng[0])
    print(i,bkng[0])
# Out:
# 0 https://www.booking.com/hotel/gb/number-eleven.es.html
# 1 https://www.booking.com/hotel/fr/1-k-hotel.es.html
# 2 https://www.booking.com/hotel/at/25hours-wien.es.html
# 3 https://www.booking.com/hotel/gb/41clubredcarnations.es.html
# 4 https://www.booking.com/hotel/gb/parklane.es.html
# 5 https://www.booking.com/hotel/gb/88-studios.es.html
# 6 https://www.booking.com/hotel/fr/9hotel-republique.es.html
# 7 https://www.booking.com/hotel/fr/a-la-villa-madame.es.html
# 8 https://www.booking.com/hotel/es/abac-barcelona.es.html
# 9 https://www.booking.com/hotel/es/achotelsbarcelona.es.html
# 10 https://www.booking.com/hotel/es/ac-marriott-diagonal-lilla.es.html
# 11 https://www.booking.com/hotel/es/acirla.es.html
# 12 https://www.booking.com/hotel/it/ac-milano.es.html
# 13 https://www.booking.com/hotel/fr/ac-paris-porte-maillot-by-marriott.es.html
# 14 https://www.booking.com/hotel/es/ac-sants.es.html

# %% [markdown]
# #### Scrapping of other Booking information (sample of 1)

# %%
import json
i = 9

# %%
head = {"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36"}
URL = bookingadress[i]
page = requests.get(URL, headers=head)
soup = BeautifulSoup(page.content, 'html.parser')
print(bookingadress[i])
# Out:
# https://www.booking.com/hotel/es/achotelsbarcelona.es.html

# %% [markdown]
# Get the Header of the page ¿?

# %%
data = soup.select("[type='application/ld+json']")[0]

# %% [markdown]
# Get the price from the Header

# %%
pricetag = json.loads(data.text)['priceRange']
price = int(pricetag.split("€",1)[1].split()[0])

# %% [markdown]
# Get the stars of the Hotel

# %%
stars = soup.find(class_='star_track')['title']

# %% [markdown]
# Get the name of the Hotel

# %%
name = json.loads(data.text)['name']

# %% [markdown]
# Get the facilities from Booking

# %%
facilities = {}
raw = soup.find_all(class_='facilitiesChecklistSection')
for i in raw:
    dept = i.getText().split('\n')
    facilities_dept = [x for x in i.getText().split('\n') if x]
    dept = facilities_dept[0]
    items = facilities_dept[1:]    
    facilities[dept] = items

# %% [markdown]
# Create the Dictionary with the data

# %%
hotels = {}
hotels[name] = {'Price': price, 'Stars': stars, 'Facilities': facilities, 'Header': json.loads(data.text)}

# %% [markdown]
# #### Scrapping of other Booking information (complete dataset for loop)

# %%
import json

# %%
head = {"User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36"}
hotels = {}

for num, url in enumerate(bookingadress):
    
    print(num, url)
    
    URL = url
    page = requests.get(URL, headers=head)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Get Header
    data = soup.select("[type='application/ld+json']")[0]
    
    # Get Hotel Name
    name = json.loads(data.text)['name']
    
    # Get Price
    pricetag = json.loads(data.text)['priceRange']
    price = int(pricetag.split("€",1)[1].split()[0])
    
    # Get Stars
    stars = soup.find(class_='star_track')['title']
    
    # Get Facilities    
    facilities = {}
    raw = soup.find_all(class_='facilitiesChecklistSection')
    for i in raw:
        dept = i.getText().split('\n')
        facilities_dept = [x for x in i.getText().split('\n') if x]
        dept = facilities_dept[0]
        items = facilities_dept[1:]    
        facilities[dept] = items
        
    # Append Information to Dicctionary
    hotels[name] = {'Price': price, 'Stars': stars, 'Facilities': facilities, 'Header': json.loads(data.text)}
# Out:
# 0 https://www.booking.com/hotel/gb/number-eleven.es.html
# 1 https://www.booking.com/hotel/fr/1-k-hotel.es.html
# 2 https://www.booking.com/hotel/at/25hours-wien.es.html
# 3 https://www.booking.com/hotel/gb/41clubredcarnations.es.html
# 4 https://www.booking.com/hotel/gb/parklane.es.html
# 5 https://www.booking.com/hotel/gb/88-studios.es.html
# 6 https://www.booking.com/hotel/fr/9hotel-republique.es.html
# 7 https://www.booking.com/hotel/fr/a-la-villa-madame.es.html
# 8 https://www.booking.com/hotel/es/abac-barcelona.es.html
# 9 https://www.booking.com/hotel/es/achotelsbarcelona.es.html
# 10 https://www.booking.com/hotel/es/ac-marriott-diagonal-lilla.es.html
# 11 https://www.booking.com/hotel/es/acirla.es.html
# 12 https://www.booking.com/hotel/it/ac-milano.es.html
# 13 https://www.booking.com/hotel/fr/ac-paris-porte-maillot-by-marriott.es.html
# 14 https://www.booking.com/hotel/es/ac-sants.es.html

# %%
hotels
# Out:
# {'11 Cadogan Gardens': {'Price': 300,
#   'Stars': 'hotel de 5 estrellas',
#   'Facilities': {'Exteriores': ['Mobiliario exterior', 'Terraza', 'Jardín'],
#    'Servicios y extras': ['Entradas para lugares de interés o espectáculos',
#     'De pago'],
#    'Mascotas': ['No se admiten.'],
#    'Actividades': ['Eventos deportivos en directo (emisión)',
#     'Fuera del alojamiento',
#     'De pago',
#     'Música / espectáculos en directo',
#     'Fuera del alojamiento',
#     'De pago',
#     'Tours a pie',
#     'De pago',
#     'Noches de cine',
#     'Fuera del alojamiento',
#     'De pago',
#     'Comedia en vivo',
#     'Fuera del alojamiento',
#     'De pago',
#     'Ruta de bares',
#     'De pago',
#     'Galerías de arte temporales',
#     'Fuera del alojamiento',
#     'Biblioteca'],
#    'Comida y bebida': ['Bombones o galletas',
#     'De pago',
#     'Fruta',
#     'De pago',
#     'Botella de agua',
#     'De pago',
#     'Vino / champán',
#     'De pago',
#     'Menú para niños',
#     'De pago',
#     'Menús dietéticos (bajo petición)',
#     'Desayuno en la habitación',
#     'Bar',
#     'Restaurante'],
#    'Accesibilidad': ['Adaptado para sillas de ruedas'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Opciones de parking disponibles',
#     'Parking adaptado para personas de movilidad reducida',
#     'Parking en la calle'],
#    'Transporte': ['Servicio de traslado al aeropuerto',
#     'De pago',
#     'Servicio de recogida en el aeropuerto',
#     'De pago'],
#    'Instalaciones de wellness': ['Gimnasio', 'Gimnasio'],
#    'Servicios de recepción': ['Servicio de conserjería',
#     'Guardaequipaje',
#     'Venta de entradas',
#     'Información turística',
#     'Recepción 24 horas'],
#    'Oferta de ocio y servicios para familias': ['Canales de TV para niños',
#     'Canguro / servicios para niños',
#     'De pago'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Plancha para pantalones',
#     'De pago',
#     'Limpiabotas',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad fuera del alojamiento',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Caja fuerte'],
#    'General': ['Zona de fumadores',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Ascensor',
#     'Suite nupcial',
#     'Habitaciones con servicios VIP',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Traslado aeropuerto',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'De pago',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Árabe',
#     'Alemán',
#     'Inglés',
#     'Español',
#     'Francés',
#     'Italiano',
#     'Polaco',
#     'Portugués']},
#   'Header': {'priceRange': 'Precios para las próximas fechas a partir de €\xa0300 por noche (igualamos el precio)',
#    '@context': 'http://schema.org',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?sensor=false&size=1600x1200&center=51.4935551,-0.1594949&markers=color:blue%7c51.4935551,-0.1594949&zoom=15&client=gme-booking&channel=booking-frontend&signature=9kk83d20fPtsE5vD909qDRLnCGQ=',
#    'description': 'Este hotel de 5 estrellas, miembro del grupo Relais & Châteaux, ofrece desayunos gourmet y habitaciones boutique con baños de mármol.',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/195/195586581.jpg',
#    '@type': 'Hotel',
#    'address': {'addressRegion': 'Gran Londres',
#     'streetAddress': '11 Cadogan Gardens, Sloane Square, Kensington y Chelsea, Londres, SW3 2RJ, Reino Unido',
#     'addressCountry': 'Reino Unido',
#     'postalCode': 'SW3 2RJ',
#     'addressLocality': '11 Cadogan Gardens, Sloane Square',
#     '@type': 'PostalAddress'},
#    'aggregateRating': {'reviewCount': 386,
#     'ratingValue': 8.7,
#     'bestRating': 10,
#     '@type': 'AggregateRating'},
#    'url': 'https://www.booking.com/hotel/gb/number-eleven.es.html',
#    'name': '11 Cadogan Gardens'}},
#  '1K Paris': {'Price': 172,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Exteriores': ['Mobiliario exterior',
#     'Terraza / solárium',
#     'Terraza'],
#    'Servicios y extras': ['Entradas para lugares de interés o espectáculos',
#     'De pago'],
#    'Mascotas': ['No se admiten.'],
#    'Actividades': ['Happy hour',
#     'Cenas temáticas',
#     'De pago',
#     'Entretenimiento nocturno',
#     'De pago'],
#    'Comida y bebida': ['Cafetería en el alojamiento',
#     'Bombones o galletas',
#     'De pago',
#     'Fruta',
#     'Botella de agua',
#     'De pago',
#     'Vino / champán',
#     'De pago',
#     'Buffet para niños',
#     'Menú para niños',
#     'De pago',
#     'Menús dietéticos (bajo petición)',
#     'Desayuno en la habitación',
#     'Bar',
#     'Restaurante',
#     '¡Buen café!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Opciones de parking disponibles', 'Parking en la calle'],
#    'Instalaciones de wellness': ['Gimnasio', 'Gimnasio'],
#    'Servicios de recepción': ['Registro de entrada / salida privado',
#     'Servicio de conserjería',
#     'Cajero automático en el hotel',
#     'Guardaequipaje',
#     'Venta de entradas',
#     'Información turística',
#     'Registro de entrada y salida exprés',
#     'Recepción 24 horas'],
#    'Oferta de ocio y servicios para familias': ['Libros, DVD, música para niños'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Plancha para pantalones',
#     'De pago',
#     'Limpiabotas',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'Centro de negocios',
#     'De pago',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad fuera del alojamiento',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Seguridad 24 horas',
#     'Caja fuerte'],
#    'General': ['Servicio de traslado',
#     'Boles para mascotas',
#     'Cesta para mascotas',
#     'Servicio de entrega de comestibles',
#     'De pago',
#     'Servicio de traslado (de pago)',
#     'Zona de fumadores',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Suite nupcial',
#     'Habitaciones familiares',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Inglés',
#     'Español',
#     'Francés',
#     'Italiano',
#     'Portugués']},
#   'Header': {'aggregateRating': {'bestRating': 10,
#     'reviewCount': 730,
#     'ratingValue': 8.4,
#     '@type': 'AggregateRating'},
#    'description': 'El 1K Hotel se encuentra en el barrio de moda de Marais y presenta un diseño inspirado en la cultura inca de Perú. Alberga un restaurante y 2 bares.',
#    'name': '1K Paris',
#    'address': {'postalCode': '75003',
#     'streetAddress': '13 Boulevard Du Temple, Le Marais - 3er distrito, 75003 París, Francia',
#     'addressCountry': 'Francia',
#     'addressLocality': '13 Boulevard Du Temple',
#     'addressRegion': 'Île-de-France',
#     '@type': 'PostalAddress'},
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/176/176551463.jpg',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?center=48.8639463,2.3658679&markers=color:blue%7c48.8639463,2.3658679&sensor=false&size=1600x1200&zoom=15&client=gme-booking&channel=booking-frontend&signature=mX4RCZMCMxrHw294fmFOi09x3us=',
#    '@type': 'Hotel',
#    '@context': 'http://schema.org',
#    'url': 'https://www.booking.com/hotel/fr/1-k-hotel.es.html',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0172 por noche (igualamos el precio)'}},
#  '25hours Hotel beim MuseumsQuartier': {'Price': 117,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Exteriores': ['Terraza / solárium', 'Terraza', 'Jardín'],
#    'Mascotas': ['Se admiten bajo petición. Se pueden aplicar suplementos.'],
#    'Actividades': ['Ciclismo',
#     'Fuera del alojamiento',
#     'Alquiler de bicicletas (de pago)'],
#    'Comida y bebida': ['Cafetería en el alojamiento',
#     'Menús dietéticos (bajo petición)',
#     'Snack-bar',
#     'Bar',
#     'Restaurante',
#     '¡Muy buen café!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Hay parking privado  en el establecimiento. No se puede reservar. Precio:  29 EUR por  día .',
#     'Parking en un garaje'],
#    'Transporte': ['Servicio de traslado al aeropuerto',
#     'De pago',
#     'Servicio de recogida en el aeropuerto',
#     'De pago'],
#    'Instalaciones de wellness': ['Taquillas en el gimnasio / spa',
#     'Gimnasio',
#     'Pediluvio',
#     'Zona de spa / relajación',
#     'Instalaciones de spa',
#     'Hammam',
#     'Spa y centro de bienestar',
#     'Gimnasio',
#     'Sauna'],
#    'Servicios de recepción': ['Servicio de conserjería',
#     'Guardaequipaje',
#     'Información turística',
#     'Recepción 24 horas'],
#    'Servicios de limpieza': ['Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'De pago',
#     'Centro de negocios',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad fuera del alojamiento',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Caja fuerte'],
#    'General': ['Boles para mascotas',
#     'Cesta para mascotas',
#     'Zona TV / salón de uso compartido',
#     'Traslado aeropuerto (de pago)',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Habitaciones hipoalergénicas',
#     'Calefacción',
#     'Alquiler de coches',
#     'Tienda de recuerdos',
#     'Ascensor',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'De pago'],
#    'Idiomas que se hablan': ['Alemán', 'Inglés']},
#   'Header': {'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?size=1600x1200&center=48.2062909,16.3546850&zoom=15&markers=color:blue%7c48.2062909,16.3546850&sensor=false&client=gme-booking&channel=booking-frontend&signature=8XTcnbpyBS3YeQP43Ny1ux68F1o=',
#    '@type': 'Hotel',
#    'name': '25hours Hotel beim MuseumsQuartier',
#    'aggregateRating': {'reviewCount': 3512,
#     '@type': 'AggregateRating',
#     'ratingValue': 8.9,
#     'bestRating': 10},
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/496/49607884.jpg',
#    'url': 'https://www.booking.com/hotel/at/25hours-wien.es.html',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0117 por noche (igualamos el precio)',
#    'address': {'addressLocality': 'Lerchenfelder Straße 1-3',
#     '@type': 'PostalAddress',
#     'postalCode': '1070',
#     'streetAddress': 'Lerchenfelder Straße 1-3, 07. Neubau, 1070 Viena, Austria',
#     'addressRegion': 'Viena',
#     'addressCountry': 'Austria'},
#    '@context': 'http://schema.org',
#    'description': 'El 25hours Hotel beim MuseumsQuartier, renovado y ampliado en 2013, ofrece una experiencia hotelera única en el animado distrito 7 de Viena, rodeado de...'}},
#  '41': {'Price': 370,
#   'Stars': 'hotel de 5 estrellas',
#   'Facilities': {'Mascotas': ['Se admiten bajo petición. Se pueden aplicar suplementos.'],
#    'Comida y bebida': ['Menús dietéticos (bajo petición)',
#     'Desayuno en la habitación',
#     'Bar',
#     'Restaurante',
#     '¡Café fantástico!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en las zonas comunes. Gratis.'],
#    'Aparcamiento': ['Hay parking público  en las inmediaciones. Es necesario reservar. Precio:  39,90 GBP por  día .'],
#    'Servicios de recepción': ['Registro de entrada / salida privado',
#     'Servicio de conserjería',
#     'Guardaequipaje',
#     'Cambio de moneda',
#     'Registro de entrada y salida exprés',
#     'Recepción 24 horas'],
#    'Oferta de ocio y servicios para familias': ['Canguro / servicios para niños',
#     'De pago'],
#    'Servicios de limpieza': ['Limpiabotas',
#     'De pago',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Centro de negocios',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'Seguridad': ['Caja fuerte'],
#    'General': ['Boles para mascotas',
#     'Cesta para mascotas',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Almuerzos para llevar',
#     'Tienda de recuerdos',
#     'Ascensor',
#     'Suite nupcial',
#     'Habitaciones con servicios VIP',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'De pago',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Afrikáans',
#     'Alemán',
#     'Inglés',
#     'Francés',
#     'Húngaro',
#     'Indonesio',
#     'Italiano',
#     'Holandés',
#     'Polaco']},
#   'Header': {'url': 'https://www.booking.com/hotel/gb/41clubredcarnations.es.html',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?sensor=false&center=51.4982207,-0.1436310&size=1600x1200&zoom=15&markers=color:blue%7c51.4982207,-0.1436310&client=gme-booking&channel=booking-frontend&signature=et2FM2pZQkr5ykPxb6av7HCPfOQ=',
#    'address': {'@type': 'PostalAddress',
#     'addressCountry': 'Reino Unido',
#     'postalCode': 'SW1W 0PS',
#     'addressRegion': 'Gran Londres',
#     'streetAddress': '41 Buckingham Palace Road, Westminster Borough, Londres, SW1W 0PS, Reino Unido',
#     'addressLocality': '41 Buckingham Palace Road'},
#    'aggregateRating': {'reviewCount': 447,
#     'bestRating': 10,
#     '@type': 'AggregateRating',
#     'ratingValue': 9.6},
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0370 por noche (igualamos el precio)',
#    'description': 'Este establecimiento de lujo se encuentra detrás del palacio de Buckingham, frente a las caballerizas reales.',
#    '@type': 'Hotel',
#    '@context': 'http://schema.org',
#    'name': '41',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/696/69698864.jpg'}},
#  '45 Park Lane - Dorchester Collection': {'Price': 824,
#   'Stars': 'hotel de 5 estrellas',
#   'Facilities': {'Mascotas': ['No se admiten.'],
#    'Actividades': ['Bicicletas disponibles (gratis)', 'Biblioteca'],
#    'Comida y bebida': ['Desayuno en la habitación',
#     'Bar',
#     'Restaurante',
#     '¡Café fantástico!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Hay parking privado  en las inmediaciones. No es necesario reservar. Precio:  50 GBP por  día .'],
#    'Instalaciones de wellness': ['Masajes', 'De pago', 'Gimnasio'],
#    'Servicios de recepción': ['Registro de entrada / salida privado',
#     'Servicio de conserjería',
#     'Guardaequipaje',
#     'Registro de entrada y salida exprés',
#     'Recepción 24 horas'],
#    'Oferta de ocio y servicios para familias': ['Canguro / servicios para niños',
#     'De pago'],
#    'Servicios de limpieza': ['Servicio de planchado',
#     'Servicio de limpieza en seco',
#     'Servicio de lavandería'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'General': ['Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Alquiler de coches',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Habitaciones con servicios VIP',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Inglés', 'Español', 'Francés', 'Italiano']},
#   'Header': {'url': 'https://www.booking.com/hotel/gb/parklane.es.html',
#    'name': '45 Park Lane - Dorchester Collection',
#    '@context': 'http://schema.org',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?sensor=false&markers=color:blue%7c51.5064962,-0.1518117&center=51.5064962,-0.1518117&zoom=15&size=1600x1200&client=gme-booking&channel=booking-frontend&signature=52LGYX37pZEBwOuxKWz9-wh7PWw=',
#    '@type': 'Hotel',
#    'address': {'streetAddress': '45 Park Lane, Westminster Borough, Londres, W1K 1PN, Reino Unido',
#     'addressLocality': '45 Park Lane',
#     '@type': 'PostalAddress',
#     'postalCode': 'W1K 1PN',
#     'addressRegion': 'Gran Londres',
#     'addressCountry': 'Reino Unido'},
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/830/8304314.jpg',
#    'aggregateRating': {'ratingValue': 9.5,
#     'reviewCount': 73,
#     'bestRating': 10,
#     '@type': 'AggregateRating'},
#    'description': 'El 45 Park Lane tiene vistas a Hyde Park, centro de fitness y asador estadounidense moderno.',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0824 por noche (igualamos el precio)'}},
#  '88 Studios': {'Price': 68,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Mascotas': ['No se admiten.'],
#    'Actividades': ['Alquiler de bicicletas (de pago)'],
#    'Comida y bebida': ['Bombones o galletas',
#     'Botella de agua',
#     '¡Buen café!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Opciones de parking disponibles', 'Parking en la calle'],
#    'Servicios de recepción': ['Servicio de conserjería',
#     'Guardaequipaje',
#     'Venta de entradas',
#     'Información turística',
#     'Recepción 24 horas'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad fuera del alojamiento',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Caja fuerte'],
#    'General': ['Zona de fumadores',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Habitaciones familiares',
#     'Habitaciones para no fumadores'],
#    'Idiomas que se hablan': ['Inglés', 'Italiano', 'Rumano']},
#   'Header': {'priceRange': 'Precios para las próximas fechas a partir de €\xa068 por noche (igualamos el precio)',
#    'url': 'https://www.booking.com/hotel/gb/88-studios.es.html',
#    'description': 'El 88 Studios se encuentra en el distrito londinense de Kensington, a solo 400 metros del centro de exposiciones Olympia.',
#    '@type': 'Hotel',
#    'address': {'addressCountry': 'Reino Unido',
#     'streetAddress': '88 Holland Road, Kensington y Chelsea, Londres, W14 8BN, Reino Unido',
#     '@type': 'PostalAddress',
#     'addressLocality': '88 Holland Road',
#     'addressRegion': 'Gran Londres',
#     'postalCode': 'W14 8BN'},
#    'aggregateRating': {'bestRating': 10,
#     '@type': 'AggregateRating',
#     'ratingValue': 8.5,
#     'reviewCount': 1734},
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?markers=color:blue%7c51.4992753,-0.2092779&sensor=false&center=51.4992753,-0.2092779&zoom=15&size=1600x1200&client=gme-booking&channel=booking-frontend&signature=XWdYn0QpZyciYz1xePOwDZrZZ-M=',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/154/154962094.jpg',
#    'name': '88 Studios',
#    '@context': 'http://schema.org'}},
#  '9Hotel Republique': {'Price': 92,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Exteriores': ['Mobiliario exterior'],
#    'Mascotas': ['No se admiten.'],
#    'Actividades': ['Eventos deportivos en directo (emisión)',
#     'Fuera del alojamiento',
#     'De pago',
#     'Música / espectáculos en directo',
#     'Fuera del alojamiento',
#     'De pago',
#     'Clases de cocina',
#     'Fuera del alojamiento',
#     'De pago',
#     'Happy hour',
#     'De pago',
#     'Cenas temáticas',
#     'Fuera del alojamiento',
#     'De pago',
#     'Tours en bici',
#     'De pago',
#     'Tours a pie',
#     'Comedia en vivo',
#     'Fuera del alojamiento',
#     'De pago',
#     'Ruta de bares',
#     'De pago',
#     'Galerías de arte temporales',
#     'Fuera del alojamiento',
#     'De pago',
#     'Biblioteca'],
#    'Comida y bebida': ['Cafetería en el alojamiento',
#     'Botella de agua',
#     'De pago',
#     'Vino / champán',
#     'De pago',
#     'Menús dietéticos (bajo petición)',
#     'Desayuno en la habitación',
#     'Bar',
#     '¡Buen café!'],
#    'Accesibilidad': ['Lavamanos más bajo',
#     'WC elevado',
#     'WC con barras de apoyo',
#     'Adaptado para sillas de ruedas'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Opciones de parking disponibles', 'Parking en la calle'],
#    'Transporte': ['Tarjetas de transporte público', 'De pago'],
#    'Instalaciones de wellness': ['Gimnasio', 'Gimnasio'],
#    'Servicios de recepción': ['Registro de entrada / salida privado',
#     'Servicio de conserjería',
#     'Guardaequipaje',
#     'Registro de entrada y salida exprés',
#     'Recepción 24 horas'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'Centro de negocios',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'Seguridad': ['Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Seguridad 24 horas',
#     'Caja fuerte'],
#    'General': ['Zona TV / salón de uso compartido',
#     'Máquina expendedora (bebidas)',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Habitaciones hipoalergénicas',
#     'Calefacción',
#     'Habitaciones insonorizadas',
#     'Tienda de recuerdos',
#     'Ascensor',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa'],
#    'Idiomas que se hablan': ['Inglés',
#     'Español',
#     'Francés',
#     'Italiano',
#     'Portugués']},
#   'Header': {'aggregateRating': {'@type': 'AggregateRating',
#     'bestRating': 10,
#     'ratingValue': 8.3,
#     'reviewCount': 986},
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa092 por noche (igualamos el precio)',
#    '@context': 'http://schema.org',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?center=48.8708613,2.3605676&markers=color:blue%7c48.8708613,2.3605676&sensor=false&size=1600x1200&zoom=15&client=gme-booking&channel=booking-frontend&signature=luFI5ITz6OaDN1qEvttOrjkV2uQ=',
#    'name': '9Hotel Republique',
#    '@type': 'Hotel',
#    'url': 'https://www.booking.com/hotel/fr/9hotel-republique.es.html',
#    'address': {'addressLocality': '7-9 Rue Pierre Chausson',
#     'addressCountry': 'Francia',
#     'addressRegion': 'Île-de-France',
#     '@type': 'PostalAddress',
#     'postalCode': '75010',
#     'streetAddress': '7-9 Rue Pierre Chausson, République - 10º distrito, 75010 París, Francia'},
#    'description': 'El 9Hotel Republique se encuentra a solo 500 metros de la plaza de la República y ofrece habitaciones con aire acondicionado y WiFi gratuita.',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/754/75434958.jpg'}},
#  'La Villa Madame': {'Price': 190,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Exteriores': ['Mobiliario exterior',
#     'Terraza / solárium',
#     'Jardín'],
#    'Servicios y extras': ['Entradas para lugares de interés o espectáculos',
#     'De pago'],
#    'Mascotas': ['No se admiten.'],
#    'Actividades': ['Música / espectáculos en directo',
#     'Fuera del alojamiento',
#     'De pago',
#     'Clases de cocina',
#     'Fuera del alojamiento',
#     'De pago',
#     'Tour o clase sobre cultura local',
#     'De pago',
#     'Tours en bici',
#     'De pago',
#     'Comedia en vivo',
#     'Fuera del alojamiento',
#     'De pago',
#     'Biblioteca'],
#    'Comida y bebida': ['Fruta',
#     'Botella de agua',
#     'Vino / champán',
#     'De pago',
#     'Menús dietéticos (bajo petición)',
#     'Desayuno en la habitación',
#     'Bar',
#     '¡Café fantástico!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Accesibilidad': ['Lavamanos más bajo',
#     'WC elevado',
#     'WC con barras de apoyo',
#     'Adaptado para sillas de ruedas'],
#    'Aparcamiento': ['Hay parking público  en las inmediaciones. No es necesario reservar. Precio:  39 EUR por  día .'],
#    'Servicios de recepción': ['Registro de entrada / salida privado',
#     'Servicio de conserjería',
#     'Guardaequipaje',
#     'Registro de entrada y salida exprés',
#     'Recepción 24 horas'],
#    'Oferta de ocio y servicios para familias': ['Juegos de mesa / puzles',
#     'Canguro / servicios para niños',
#     'De pago'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Seguridad 24 horas'],
#    'General': ['Traslado aeropuerto (de pago)',
#     'Zona de fumadores',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Habitaciones hipoalergénicas',
#     'Calefacción',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Inglés', 'Español', 'Francés', 'Portugués']},
#   'Header': {'@type': 'Hotel',
#    'address': {'addressRegion': 'Île-de-France',
#     'postalCode': '75006',
#     'addressLocality': '44 Rue Madame',
#     '@type': 'PostalAddress',
#     'addressCountry': 'Francia',
#     'streetAddress': '44 Rue Madame, Saint-Germain - 6º distrito, 75006 París, Francia'},
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0190 por noche (igualamos el precio)',
#    'description': 'El hotel La Villa Madame se encuentra en el distrito 6º de París, en Saint-Germain-des-Prés.',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?zoom=15&size=1600x1200&sensor=false&markers=color:blue%7c48.8488427,2.3316282&center=48.8488427,2.3316282&client=gme-booking&channel=booking-frontend&signature=iRBs5lDjfPvyZSFPq1SfI1yLmhs=',
#    'url': 'https://www.booking.com/hotel/fr/a-la-villa-madame.es.html',
#    '@context': 'http://schema.org',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/695/6958077.jpg',
#    'aggregateRating': {'@type': 'AggregateRating',
#     'bestRating': 10,
#     'reviewCount': 219,
#     'ratingValue': 8.9},
#    'name': 'La Villa Madame'}},
#  'ABaC Restaurant Hotel Barcelona GL Monumento': {'Price': 217,
#   'Stars': 'hotel de 5 estrellas',
#   'Facilities': {'Exteriores': ['Mobiliario exterior', 'Terraza', 'Jardín'],
#    'Mascotas': ['No se admiten.'],
#    'Actividades': ['Alquiler de bicicletas (de pago)'],
#    'Comida y bebida': ['Cafetería en el alojamiento',
#     'Bombones o galletas',
#     'De pago',
#     'Fruta',
#     'De pago',
#     'Vino / champán',
#     'De pago',
#     'Desayuno en la habitación',
#     'Bar',
#     'Restaurante',
#     '¡Muy buen café!'],
#    'Accesibilidad': ['WC con barras de apoyo',
#     'Adaptado para sillas de ruedas'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Hay parking privado  en el establecimiento. Es necesario reservar. Precio:  40 EUR por  día .',
#     'Parking adaptado para personas de movilidad reducida',
#     'Estación de carga de vehículos eléctricos',
#     'Parking vigilado'],
#    'Piscina y bienestar': ['Piscina',
#     'Taquillas en el gimnasio / spa',
#     'Gimnasio',
#     'Silla de masajes',
#     'Paquetes de spa / bienestar',
#     'Zona de spa / relajación',
#     'Baño de vapor',
#     'Instalaciones de spa',
#     'Envoltura corporal',
#     'Exfoliación corporal',
#     'Tratamientos corporales',
#     'Tratamientos faciales',
#     'Servicios de belleza',
#     'Tumbonas/sillas de playa',
#     'Piscina cubierta',
#     'Piscina climatizada',
#     'Piscina interior (todo el año)',
#     'Piscina interior',
#     'Hammam',
#     'Bañera de hidromasaje / jacuzzi',
#     'Masajes',
#     'De pago',
#     'Spa y centro de bienestar',
#     'Gimnasio',
#     'Sauna'],
#    'Servicios de recepción': ['Registro de entrada / salida privado',
#     'Servicio de conserjería',
#     'Guardaequipaje',
#     'Venta de entradas',
#     'Información turística',
#     'Recepción 24 horas'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Plancha para pantalones',
#     'De pago',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'De pago',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad fuera del alojamiento',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Caja fuerte'],
#    'General': ['Servicio de traslado',
#     'Solo para adultos',
#     'Traslado aeropuerto (de pago)',
#     'Servicio de traslado (de pago)',
#     'Zona de fumadores',
#     'Aire acondicionado',
#     'Habitaciones hipoalergénicas',
#     'Calefacción',
#     'Alquiler de coches',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Suite nupcial',
#     'Habitaciones con servicios VIP',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Catalán', 'Inglés', 'Español', 'Francés']},
#   'Header': {'description': 'El ABaC Restaurant Hotel Barcelona GL Monumento cuenta con un restaurante estrella Michelin, spa y habitaciones elegantes con smart TV Samsung 4K, WiFi...',
#    'url': 'https://www.booking.com/hotel/es/abac-barcelona.es.html',
#    '@type': 'Hotel',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?center=41.4107233,2.1364593&markers=color:blue%7c41.4107233,2.1364593&sensor=false&zoom=15&size=1600x1200&client=gme-booking&channel=booking-frontend&signature=NhNabNaVIN7Jsm4eS8d2G-kU_Bk=',
#    '@context': 'http://schema.org',
#    'aggregateRating': {'bestRating': 10,
#     'ratingValue': 9.0,
#     '@type': 'AggregateRating',
#     'reviewCount': 159},
#    'name': 'ABaC Restaurant Hotel Barcelona GL Monumento',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/226/226459677.jpg',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0217 por noche (igualamos el precio)',
#    'address': {'postalCode': '08022',
#     '@type': 'PostalAddress',
#     'addressCountry': 'España',
#     'streetAddress': 'Avenida Tibidabo, 1, Sarrià-Sant Gervasi, 08022 Barcelona, España',
#     'addressLocality': 'Avenida Tibidabo, 1',
#     'addressRegion': 'Cataluña'}}},
#  'AC Hotel Barcelona Forum': {'Price': 81,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Exteriores': ['Terraza / solárium', 'Terraza'],
#    'Mascotas': ['No se admiten.'],
#    'Comida y bebida': ['Snack-bar',
#     'Desayuno en la habitación',
#     'Bar',
#     'Restaurante',
#     '¡Muy buen café!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Hay parking privado  en el establecimiento. No se puede reservar. Precio:  24 EUR por  día .'],
#    'Piscina y bienestar': ['Piscina', 'Piscina al aire libre', 'Gimnasio'],
#    'Servicios de recepción': ['Guardaequipaje',
#     'Información turística',
#     'Cambio de moneda',
#     'Recepción 24 horas'],
#    'Servicios de limpieza': ['Servicio de planchado',
#     'Servicio de limpieza en seco',
#     'Servicio de lavandería'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'Centro de negocios',
#     'Salas de reuniones / banquetes'],
#    'Seguridad': ['Extintores',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Seguridad 24 horas'],
#    'General': ['Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Habitaciones hipoalergénicas',
#     'Calefacción',
#     'Alquiler de coches',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Inglés', 'Español', 'Francés', 'Italiano']},
#   'Header': {'@context': 'http://schema.org',
#    'aggregateRating': {'ratingValue': 8.4,
#     'bestRating': 10,
#     '@type': 'AggregateRating',
#     'reviewCount': 1528},
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/182/182017513.jpg',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?zoom=15&size=1600x1200&markers=color:blue%7c41.4103391,2.2191820&sensor=false&center=41.4103391,2.2191820&client=gme-booking&channel=booking-frontend&signature=o9o2mdruZ3Vwn8eErPBlJ4N7Ouw=',
#    '@type': 'Hotel',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa081 por noche (igualamos el precio)',
#    'url': 'https://www.booking.com/hotel/es/achotelsbarcelona.es.html',
#    'description': 'El AC Hotel Barcelona Forum se encuentra frente al centro comercial Diagonal Mar, al final de la avenida Diagonal.',
#    'address': {'@type': 'PostalAddress',
#     'addressLocality': 'Paseo Taulat, 278',
#     'postalCode': '08019',
#     'streetAddress': 'Paseo Taulat, 278, Sant Martí, 08019 Barcelona, España',
#     'addressCountry': 'España',
#     'addressRegion': 'Cataluña'},
#    'name': 'AC Hotel Barcelona Forum'}},
#  'AC Hotel Diagonal LÂ´Illa': {'Price': 92,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Exteriores': ['Terraza'],
#    'Mascotas': ['No se admiten.'],
#    'Comida y bebida': ['Snack-bar',
#     'Desayuno en la habitación',
#     'Bar',
#     '¡Muy buen café!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Hay parking privado  en el establecimiento. No se puede reservar. Precio:  40 EUR por  día .'],
#    'Instalaciones de wellness': ['Gimnasio'],
#    'Servicios de recepción': ['Guardaequipaje',
#     'Información turística',
#     'Registro de entrada y salida exprés',
#     'Recepción 24 horas'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Plancha para pantalones',
#     'De pago',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'General': ['Servicio de traslado',
#     'Zona TV / salón de uso compartido',
#     'Servicio de traslado (de pago)',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Alquiler de coches',
#     'Ascensor',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Catalán',
#     'Alemán',
#     'Inglés',
#     'Español',
#     'Francés',
#     'Italiano']},
#   'Header': {'aggregateRating': {'bestRating': 10,
#     'reviewCount': 405,
#     'ratingValue': 8.8,
#     '@type': 'AggregateRating'},
#    'url': 'https://www.booking.com/hotel/es/ac-marriott-diagonal-lilla.es.html',
#    'address': {'streetAddress': 'Avenida Diagonal, 555, Les Corts, 08029 Barcelona, España',
#     'addressLocality': 'Avenida Diagonal, 555',
#     'postalCode': '08029',
#     'addressRegion': 'Cataluña',
#     '@type': 'PostalAddress',
#     'addressCountry': 'España'},
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa092 por noche (igualamos el precio)',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?center=41.3899540,2.1358437&size=1600x1200&markers=color:blue%7c41.3899540,2.1358437&sensor=false&zoom=15&client=gme-booking&channel=booking-frontend&signature=OaDH35YfPur-l81XrwqJT9gq0ZU=',
#    'name': 'AC Hotel Diagonal LÂ´Illa',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/521/52132931.jpg',
#    'description': 'El AC Hotel Diagonal L´Illa ofrece alojamiento en Barcelona, \u200b\u200ba 1,8 km del Camp Nou.',
#    '@context': 'http://schema.org',
#    '@type': 'Hotel'}},
#  'AC Hotel Irla': {'Price': 101,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Mascotas': ['No se admiten.'],
#    'Comida y bebida': ['Snack-bar', 'Desayuno en la habitación', 'Bar'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Hay parking público  en las inmediaciones. No se puede reservar. Precio:  24 EUR por  día .'],
#    'Instalaciones de wellness': ['Hammam', 'Gimnasio'],
#    'Servicios de recepción': ['Guardaequipaje',
#     'Información turística',
#     'Recepción 24 horas'],
#    'Servicios de limpieza': ['Limpiabotas',
#     'Servicio de planchado',
#     'Servicio de limpieza en seco',
#     'Servicio de lavandería'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'Centro de negocios',
#     'Salas de reuniones / banquetes'],
#    'Seguridad': ['Caja fuerte'],
#    'General': ['Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Alquiler de coches',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Inglés', 'Español']},
#   'Header': {'image': 'https://r-cf.bstatic.com/images/hotel/max500/230/230957834.jpg',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0101 por noche (igualamos el precio)',
#    'address': {'addressCountry': 'España',
#     'postalCode': '08021',
#     'streetAddress': 'Calvet, 40-42, Sarrià-Sant Gervasi, 08021 Barcelona, España',
#     'addressRegion': 'Cataluña',
#     '@type': 'PostalAddress',
#     'addressLocality': 'Calvet, 40-42'},
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?sensor=false&zoom=15&size=1600x1200&center=41.3947913,2.1434256&markers=color:blue%7c41.3947913,2.1434256&client=gme-booking&channel=booking-frontend&signature=jA4uveP82aW7vnuh5BBdCU9lnnY=',
#    'name': 'AC Hotel Irla',
#    'aggregateRating': {'bestRating': 10,
#     'ratingValue': 8.0,
#     'reviewCount': 58,
#     '@type': 'AggregateRating'},
#    '@type': 'Hotel',
#    '@context': 'http://schema.org',
#    'url': 'https://www.booking.com/hotel/es/acirla.es.html',
#    'description': 'El AC Hotel Irla está situado a 200 metros de la avenida Diagonal y de la plaza Francesc Macià.'}},
#  'AC Hotel Milano': {'Price': 103,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Mascotas': ['No se admiten.'],
#    'Actividades': ['Happy hour', 'De pago'],
#    'Comida y bebida': ['Botella de agua',
#     'Snack-bar',
#     'Desayuno en la habitación',
#     'Bar',
#     'Restaurante',
#     '¡Muy buen café!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en todo el establecimiento. Gratis.'],
#    'Aparcamiento': ['Hay parking privado  en el establecimiento. No se puede reservar. Precio:  26 EUR por  día .',
#     'Parking adaptado para personas de movilidad reducida',
#     'Parking en un garaje',
#     'Parking en la calle',
#     'Parking vigilado'],
#    'Instalaciones de wellness': ['Gimnasio', 'Gimnasio'],
#    'Servicios de recepción': ['Guardaequipaje', 'Recepción 24 horas'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Plancha para pantalones',
#     'Limpiabotas',
#     'Servicio de planchado',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'De pago',
#     'Salas de reuniones / banquetes',
#     'De pago'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Seguridad 24 horas',
#     'Caja fuerte'],
#    'General': ['Servicio de traslado',
#     'Servicio de traslado (de pago)',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Habitaciones hipoalergénicas',
#     'Calefacción',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Suite nupcial',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Árabe',
#     'Inglés',
#     'Español',
#     'Francés',
#     'Italiano',
#     'Holandés',
#     'Ruso']},
#   'Header': {'@type': 'Hotel',
#    'description': 'El AC Hotel Milano se encuentra a 300 metros de la estación de Porta Garibaldi, que proporciona conexiones con el centro de exposiciones de Rho y está muy...',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0103 por noche (igualamos el precio)',
#    'aggregateRating': {'ratingValue': 8.6,
#     'reviewCount': 718,
#     'bestRating': 10,
#     '@type': 'AggregateRating'},
#    'name': 'AC Hotel Milano',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/157/157685519.jpg',
#    'url': 'https://www.booking.com/hotel/it/ac-milano.es.html',
#    'address': {'addressCountry': 'Italia',
#     'addressRegion': 'Lombardía',
#     'addressLocality': 'Via Tazzoli 2',
#     'postalCode': '20154',
#     '@type': 'PostalAddress',
#     'streetAddress': 'Via Tazzoli 2, Estación Garibaldi, 20154 Milán, Italia'},
#    '@context': 'http://schema.org',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?markers=color:blue%7c45.4851823,9.1831353&zoom=15&center=45.4851823,9.1831353&size=1600x1200&sensor=false&client=gme-booking&channel=booking-frontend&signature=OxALv179m9UQHQ1Zj-y9sIPxeTY='}},
#  'AC Hotel Paris Porte Maillot by Marriott': {'Price': 149,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Servicios y extras': ['Entradas para lugares de interés o espectáculos',
#     'De pago'],
#    'Mascotas': ['Se admiten bajo petición. Se pueden aplicar suplementos.'],
#    'Actividades': ['Eventos deportivos en directo (emisión)',
#     'Happy hour',
#     'De pago'],
#    'Comida y bebida': ['Cafetería en el alojamiento',
#     'Bombones o galletas',
#     'De pago',
#     'Fruta',
#     'De pago',
#     'Botella de agua',
#     'Vino / champán',
#     'De pago',
#     'Snack-bar',
#     'Desayuno en la habitación',
#     'Bar',
#     '¡Muy buen café!'],
#    'Internet': ['¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en las zonas comunes. Gratis.'],
#    'Accesibilidad': ['Lavamanos más bajo',
#     'WC elevado',
#     'WC con barras de apoyo',
#     'Adaptado para sillas de ruedas'],
#    'Aparcamiento': ['Hay parking privado  en el establecimiento. Es necesario reservar. Precio:  25 EUR por  día .',
#     'Parking adaptado para personas de movilidad reducida',
#     'Parking en un garaje',
#     'Parking en la calle',
#     'Parking vigilado'],
#    'Instalaciones de wellness': ['Gimnasio', 'Gimnasio'],
#    'Servicios de recepción': ['Registro de entrada / salida privado',
#     'Servicio de conserjería',
#     'Guardaequipaje',
#     'Venta de entradas',
#     'Recepción 24 horas'],
#    'Oferta de ocio y servicios para familias': ['Canales de TV para niños'],
#    'Servicios de limpieza': ['Servicio de limpieza diario',
#     'Servicio de planchado',
#     'De pago',
#     'Servicio de limpieza en seco',
#     'De pago',
#     'Servicio de lavandería',
#     'De pago'],
#    'Instalaciones de negocios': ['Fax / fotocopiadora',
#     'De pago',
#     'Centro de negocios'],
#    'Seguridad': ['Extintores',
#     'Cámaras de seguridad fuera del alojamiento',
#     'Cámaras de seguridad en las zonas comunitarias',
#     'Detectores de humo',
#     'Alarma de seguridad',
#     'Caja fuerte'],
#    'General': ['Supermercado pequeño en el alojamiento',
#     'Traslado aeropuerto (de pago)',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Habitaciones hipoalergénicas',
#     'Calefacción',
#     'Habitaciones insonorizadas',
#     'Ascensor',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa',
#     'Servicio de habitaciones'],
#    'Idiomas que se hablan': ['Alemán',
#     'Inglés',
#     'Español',
#     'Francés',
#     'Chino']},
#   'Header': {'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?center=48.8819849,2.2820207&markers=color:blue%7c48.8819849,2.2820207&size=1600x1200&sensor=false&zoom=15&client=gme-booking&channel=booking-frontend&signature=jzFkQ92YrdRQG5WhyqJrupev4Jw=',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa0149 por noche (igualamos el precio)',
#    '@context': 'http://schema.org',
#    'address': {'postalCode': '75017',
#     'addressLocality': '6 rue Gustave Charpentier',
#     '@type': 'PostalAddress',
#     'streetAddress': '6 rue Gustave Charpentier, Batignolles - 17º distrito, 75017 París, Francia',
#     'addressCountry': 'Francia',
#     'addressRegion': 'Île-de-France'},
#    'aggregateRating': {'bestRating': 10,
#     '@type': 'AggregateRating',
#     'ratingValue': 8.4,
#     'reviewCount': 245},
#    '@type': 'Hotel',
#    'name': 'AC Hotel Paris Porte Maillot by Marriott',
#    'url': 'https://www.booking.com/hotel/fr/ac-paris-porte-maillot-by-marriott.es.html',
#    'description': 'El AC Hotel Paris Porte Maillot by Marriott ofrece un alojamiento moderno en París, a 5 minutos a pie del centro Palais des Congrès y a 3 km del distrito...',
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/347/34746130.jpg'}},
#  'AC Hotel Sants': {'Price': 95,
#   'Stars': 'hotel de 4 estrellas',
#   'Facilities': {'Mascotas': ['No se admiten.'],
#    'Comida y bebida': ['Cafetería en el alojamiento',
#     'Snack-bar',
#     'Bar',
#     'Restaurante',
#     '¡Muy buen café!'],
#    'Internet': ['Hay conexión a internet Wi-Fi disponible en las habitaciones. Precio:  6,50 EUR por hora .',
#     'Hay conexión a internet Wi-Fi disponible en las habitaciones. Precio:  12 EUR por 24 horas .',
#     '¡Gratis!',
#     'Hay conexión a internet Wi-Fi disponible en las zonas comunes. Gratis.'],
#    'Aparcamiento': ['Hay parking privado  en las inmediaciones. No es necesario reservar. Precio:  19,36 EUR por  día .',
#     'Parking adaptado para personas de movilidad reducida',
#     'Parking en un garaje'],
#    'Instalaciones de wellness': ['Gimnasio', 'Gimnasio'],
#    'Servicios': ['Servicio de conserjería',
#     'Fax / fotocopiadora',
#     'Cambio de moneda',
#     'Servicio de lavandería',
#     'De pago',
#     'Recepción 24 horas',
#     'Salas de reuniones / banquetes',
#     'De pago',
#     'Servicio de habitaciones'],
#    'Seguridad': ['Caja fuerte'],
#    'General': ['WiFi de pago',
#     'Aire acondicionado',
#     'Prohibido fumar en todo el alojamiento',
#     'Calefacción',
#     'Ascensor',
#     'Habitaciones familiares',
#     'Adaptado personas de movilidad reducida',
#     'Habitaciones para no fumadores',
#     'Prensa'],
#    'Idiomas que se hablan': ['Inglés', 'Español']},
#   'Header': {'address': {'addressRegion': 'Cataluña',
#     'streetAddress': 'Passeig de Sant Antoni, 36-40, Sants-Montjuïc, 08014 Barcelona, España',
#     'addressLocality': 'Passeig de Sant Antoni, 36-40',
#     '@type': 'PostalAddress',
#     'postalCode': '08014',
#     'addressCountry': 'España'},
#    'description': 'El AC Hotel Sants se encuentra a solo 50 metros de la estación de tren Sants de Barcelona.',
#    'priceRange': 'Precios para las próximas fechas a partir de €\xa095 por noche (igualamos el precio)',
#    'url': 'https://www.booking.com/hotel/es/ac-sants.es.html',
#    'aggregateRating': {'reviewCount': 380,
#     'ratingValue': 8.3,
#     '@type': 'AggregateRating',
#     'bestRating': 10},
#    'image': 'https://r-cf.bstatic.com/images/hotel/max500/120/120941492.jpg',
#    'name': 'AC Hotel Sants',
#    '@type': 'Hotel',
#    '@context': 'http://schema.org',
#    'hasMap': 'https://maps.googleapis.com/maps/api/staticmap?center=41.3774888,2.1388364&sensor=false&zoom=15&markers=color:blue%7c41.3774888,2.1388364&size=1600x1200&client=gme-booking&channel=booking-frontend&signature=pMPp8lAsvrRTO-3Wmp293sjMHB8='}}}

# %%
[i for i in hotels]
# Out:
# ['11 Cadogan Gardens',
#  '1K Paris',
#  '25hours Hotel beim MuseumsQuartier',
#  '41',
#  '45 Park Lane - Dorchester Collection',
#  '88 Studios',
#  '9Hotel Republique',
#  'La Villa Madame',
#  'ABaC Restaurant Hotel Barcelona GL Monumento',
#  'AC Hotel Barcelona Forum',
#  'AC Hotel Diagonal LÂ´Illa',
#  'AC Hotel Irla',
#  'AC Hotel Milano',
#  'AC Hotel Paris Porte Maillot by Marriott',
#  'AC Hotel Sants']

# %%
for i in hotels:
    print(i, hotels[i]['Price'], hotels[i]['Stars'])
# Out:
# 11 Cadogan Gardens 300 hotel de 5 estrellas
# 1K Paris 172 hotel de 4 estrellas
# 25hours Hotel beim MuseumsQuartier 117 hotel de 4 estrellas
# 41 370 hotel de 5 estrellas
# 45 Park Lane - Dorchester Collection 824 hotel de 5 estrellas
# 88 Studios 68 hotel de 4 estrellas
# 9Hotel Republique 92 hotel de 4 estrellas
# La Villa Madame 190 hotel de 4 estrellas
# ABaC Restaurant Hotel Barcelona GL Monumento 217 hotel de 5 estrellas
# AC Hotel Barcelona Forum 81 hotel de 4 estrellas
# AC Hotel Diagonal LÂ´Illa 92 hotel de 4 estrellas
# AC Hotel Irla 101 hotel de 4 estrellas
# AC Hotel Milano 103 hotel de 4 estrellas
# AC Hotel Paris Porte Maillot by Marriott 149 hotel de 4 estrellas
# AC Hotel Sants 95 hotel de 4 estrellas
